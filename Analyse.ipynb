# %%
import pandas as pd

# %%
df = pd.read_csv("effects-of-covid-19-on-trade-at-15-december-2021-provisional.csv", encoding='ISO-8859-1')

# %%
year = df.set_index("Year")

# %%
year.loc[[2018,2019]]
# Out:
#       Direction        Date    Weekday Country Commodity Transport_Mode  \
# Year
# 2018    Exports  01/01/2018     Monday     All       All            All
# 2018    Exports  02/01/2018    Tuesday     All       All            All
# 2018    Exports  03/01/2018  Wednesday     All       All            All
# 2018    Exports  04/01/2018   Thursday     All       All            All
# 2018    Exports  05/01/2018     Friday     All       All            All
# ...         ...         ...        ...     ...       ...            ...
# 2019  Reimports  26/12/2019   Thursday     All       All            All
# 2019  Reimports  27/12/2019     Friday     All       All            All
# 2019  Reimports  29/12/2019     Sunday     All       All            All
# 2019  Reimports  30/12/2019     Monday     All       All            All
# 2019  Reimports  31/12/2019    Tuesday     All       All            All
#
#      Measure      Value  Cumulative
# Year
# 2018       $   65000000    65000000
# ...

# %%
# Out:
#          Direction  Year        Date Country Commodity Transport_Mode Measure  \
# Weekday
# Tuesday    Exports  2015  06/01/2015     All       All            All       $
# Tuesday    Exports  2015  13/01/2015     All       All            All       $
# Tuesday    Exports  2015  20/01/2015     All       All            All       $
# Tuesday    Exports  2015  27/01/2015     All       All            All       $
# Tuesday    Exports  2015  03/02/2015     All       All            All       $
# ...            ...   ...         ...     ...       ...            ...     ...
# Monday   Reimports  2021  15/11/2021     All       All            All       $
# Monday   Reimports  2021  22/11/2021     All       All            All       $
# Monday   Reimports  2021  29/11/2021     All       All            All       $
# Monday   Reimports  2021  06/12/2021     All       All            All       $
# Monday   Reimports  2021  13/12/2021     All       All            All       $
#
# ...

# %%
TM = wd.loc[['Tuesday','Monday']]

# %%
TM.Value = 1

# %%
df.groupby("Year")["Cumulative"].sum().plot()
# Out:
# <Axes: xlabel='Year'>

# %%
year89 = year.set_index("Date")

# %%
year89.loc[["05/01/2018","26/12/2018"]]
# Out:
#             Direction    Weekday        Country  \
# Date
# 05/01/2018    Exports     Friday            All
# 05/01/2018    Exports     Friday          China
# 05/01/2018    Exports     Friday      Australia
# 05/01/2018    Exports     Friday  United States
# 05/01/2018    Exports     Friday          Japan
# ...               ...        ...            ...
# 26/12/2018    Imports  Wednesday            All
# 26/12/2018    Imports  Wednesday          China
# 26/12/2018    Imports  Wednesday          China
# 26/12/2018    Imports  Wednesday            All
# 26/12/2018  Reimports  Wednesday            All
#
#                                  Commodity Transport_Mode Measure      Value  \
# Date
# 05/01/2018                             All            All       $  105000000
# 05/01/2018                             All            All       $   32000000
# 05/01/2018                             All            All       $   14000000
# ...

# %%
DT = year89.loc[["05/01/2018","26/12/2020"]]

# %%
DT.groupby("Date")["Cumulative"].sum().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
cmmd = df.set_index("Commodity")

# %%
cmmd.loc['Electrical machinery and equip']
# Out:
#                                 Direction  Year        Date    Weekday  \
# Commodity
# Electrical machinery and equip    Exports  2015  01/01/2015   Thursday
# Electrical machinery and equip    Exports  2015  02/01/2015     Friday
# Electrical machinery and equip    Exports  2015  03/01/2015   Saturday
# Electrical machinery and equip    Exports  2015  04/01/2015     Sunday
# Electrical machinery and equip    Exports  2015  05/01/2015     Monday
# ...                                   ...   ...         ...        ...
# Electrical machinery and equip  Reimports  2021  11/12/2021   Saturday
# Electrical machinery and equip  Reimports  2021  12/12/2021     Sunday
# Electrical machinery and equip  Reimports  2021  13/12/2021     Monday
# Electrical machinery and equip  Reimports  2021  14/12/2021    Tuesday
# Electrical machinery and equip  Reimports  2021  15/12/2021  Wednesday
#
#                                Country Transport_Mode Measure      Value  \
# Commodity
# ...

# %%
cmmd.groupby("Year")["Value"].sum().plot()
# Out:
# <Axes: xlabel='Year'>

# %%
cmmd.groupby("Year")["Value"].sum().plot.bar()
# Out:
# <Axes: xlabel='Year'>

# %%
cmmd.groupby("Year")["Value"].sum().plot.pie()
# Out:
# <Axes: ylabel='Value'>

# %%
Ctry = cmmd.loc['Electrical machinery and equip']

# %%
Pays =  Ctry.set_index('Country')

# %%
Pays.loc['China']
# Out:
#         Direction  Year        Date    Weekday Transport_Mode Measure  \
# Country
# China     Exports  2015  01/01/2015   Thursday            All       $
# China     Exports  2015  02/01/2015     Friday            All       $
# China     Exports  2015  03/01/2015   Saturday            All       $
# China     Exports  2015  04/01/2015     Sunday            All       $
# China     Exports  2015  05/01/2015     Monday            All       $
# ...           ...   ...         ...        ...            ...     ...
# China     Imports  2021  11/12/2021   Saturday            All       $
# China     Imports  2021  12/12/2021     Sunday            All       $
# China     Imports  2021  13/12/2021     Monday            All       $
# China     Imports  2021  14/12/2021    Tuesday            All       $
# China     Imports  2021  15/12/2021  Wednesday            All       $
#
#             Value  Cumulative
# Country
# China    20000000    20000000
# China    20000000    40000000
# ...

# %%
Ch = Pays.loc['China']

# %%
Ch.groupby("Year")["Value"].sum().plot()
# Out:
# <Axes: xlabel='Year'>

# %%
ChDirections = Ch.set_index("Direction")

# %%
ChDirections
# Out:
#            Year        Date    Weekday Transport_Mode Measure     Value  \
# Direction
# Exports    2015  01/01/2015   Thursday            All       $  20000000
# Exports    2015  02/01/2015     Friday            All       $  20000000
# Exports    2015  03/01/2015   Saturday            All       $  11000000
# Exports    2015  04/01/2015     Sunday            All       $   8000000
# Exports    2015  05/01/2015     Monday            All       $  16000000
# ...         ...         ...        ...            ...     ...       ...
# Imports    2021  11/12/2021   Saturday            All       $   2000000
# Imports    2021  12/12/2021     Sunday            All       $   1000000
# Imports    2021  13/12/2021     Monday            All       $  25000000
# Imports    2021  14/12/2021    Tuesday            All       $  25000000
# Imports    2021  15/12/2021  Wednesday            All       $  14000000
#
#            Cumulative
# Direction
# Exports      20000000
# Exports      40000000
# ...

# %%
Ch_imports
# Out:
#            Year        Date    Weekday Transport_Mode Measure     Value  \
# Direction
# Imports    2015  01/01/2015   Thursday            All       $   8000000
# Imports    2015  02/01/2015     Friday            All       $   5000000
# Imports    2015  03/01/2015   Saturday            All       $   2000000
# Imports    2015  04/01/2015     Sunday            All       $   7000000
# Imports    2015  05/01/2015     Monday            All       $  40000000
# ...         ...         ...        ...            ...     ...       ...
# Imports    2021  11/12/2021   Saturday            All       $   2000000
# Imports    2021  12/12/2021     Sunday            All       $   1000000
# Imports    2021  13/12/2021     Monday            All       $  25000000
# Imports    2021  14/12/2021    Tuesday            All       $  25000000
# Imports    2021  15/12/2021  Wednesday            All       $  14000000
#
#            Cumulative
# Direction
# Imports       8000000
# Imports      14000000
# ...

# %%
Ch_imports = ChDirections.loc['Imports']

# %%
Ch_exports = ChDirections.loc['Exports']

# %%
Ch_imports.groupby("Year")["Value"].sum().plot()
# Out:
# <Axes: xlabel='Year'>

# %%
Ch_exports.groupby("Year")["Value"].sum().plot()
# Out:
# <Axes: xlabel='Year'>
